# %% [markdown]
# # Exploratory Data Analysis of the National Financial Capability Study Survey Report

# %%
# DECISION TREE MODEL
X = finance.drop('too_much_debt', axis = 1)
y = finance.too_much_debt.reshape(81219,1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify = y)

from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(max_depth = 3, criterion = 'entropy', min_samples_split=2, min_samples_leaf=1)

tree.fit(X_train, y_train)
tree.score(X_train, y_train), tree.score(X_test, y_test)

y_pred= tree.predict(X_test)

print(metrics.accuracy_score(y_test, y_pred))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set(style="white", context="talk")

# %%
eda = pd.read_csv(r"C:\Users\578735\Desktop\5KCapstone\Medical_debt\NFCS_EDA.csv",  low_memory=False)

# %%
# eda.too_much_debt.dropna(inplace=True)

# %%
# getting rid of NaN Values
eda = eda[np.isfinite(eda['too_much_debt'])]

# %%
# changing finance type to integers
eda["too_much_debt"] = eda["too_much_debt"].astype(int)

# %%
# changing finance type to integers
eda["year"] = eda["year"].astype(int)

# %%
eda.too_much_debt.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        2
# 1        1
# 2        1
# 3        2
# 4        1
# 5        1
# 6        2
# 7        2
# 8        2
# 9        1
# 10       3
# 11       3
# 12       1
# 13       1
# 14       2
# 15       1
# 16       1
# 17       1
# 18       1
# 19       1
# 20       1
# 21       3
# 22       1
# 24       1
# 25       2
# 26       1
# 27       3
# 28       1
# 29       2
# 30       2
#         ..
# 77599    1
# 77600    1
# 77601    2
# 77602    2
# 77603    2
# 77604    3
# 77605    3
# 77606    3
# 77607    1
# 77608    2
# 77609    3
# 77610    3
# 77611    3
# 77612    1
# 77613    2
# 77615    1
# 77616    1
# 77617    3
# 77618    2
# 77619    1
# 77620    2
# 77621    2
# 77622    2
# 77623    3
# 77624    2
# 77625    1
# 77626    1
# 77627    2
# 77628    2
# 77629    3
# Name: too_much_debt, Length: 52371, dtype: int32>

# %%
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['font.size'] = 14.0
mosaic(eda, ['region_usa', 'pay_full_bill_credit_card']);

# %%
#Countplot of army status, with respect to gender 
# plt.figure(figsize = (12, 6))
sns.set(rc={"figure.figsize": (10, 7)})
ax = sns.countplot(x='army_status_indv', data=eda, 
#                  order = ["Not Good at Budgeting", "OK at Budgeting", "Great at Budgeting"], 
                 hue= 'marital_status', palette='RdBu_r').set_title("Army Status", fontsize = 16)

# %%
#Countplot of budgeting habits, with respect to gender 
# plt.figure(figsize = (12, 6))
sns.set(rc={"figure.figsize": (10, 7)})
ax = sns.countplot(x='budgeting', data=eda, 
                 order = ["Not Good at Budgeting", "OK at Budgeting", "Great at Budgeting"], 
                 hue= 'gender', palette='RdBu_r').set_title("Budgeting Habits", fontsize = 16)

# %%
#Countplot of satisfaction with finance knowledge with respect to age 

# plt.figure(figsize = (12, 6))
sns.set(rc={"figure.figsize": (10, 9)})
ax = sns.countplot(x='finance_knowledge', data=eda, order = ["Very Low", "Moderate Knowledge", "Very High"],
             hue= 'age_group', hue_order = ["18-24 yo", "25-34 yo", "35-44 yo", "45-54 yo", "55-64 yo", "65+ yo"], palette='summer').set_title("Financial Knowledge", fontsize = 16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#Barplot of how much debt one has based on math ability

# plt.figure(figsize = (12, 6))
sns.set(rc={"figure.figsize": (11, 8)})
ax = sns.countplot(x='good_at_math', 
                 data=eda, hue= 'ethnicity', palette='Set3').set_title("Math Literacy", fontsize = 16)

# %%
#Countplot of finance education with respect to gender

# plt.figure(figsize = (12, 6))
sns.set(rc={"figure.figsize": (10, 9)})
ax = sns.countplot(x='finance_education', data=eda, order = ["Yes, Participated", "Yes, but did not Participate", "No"],
             hue= 'gender', hue_order = ["Female", "Male"], palette='winter').set_title("Finance Education In School or Company", fontsize = 16)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)


# # plt.figure(figsize = (12, 6))
# sns.set(rc={"figure.figsize": (10, 7)})
# ax = sns.barplot(x='finance_education', hue= 'gender',
#                  data=eda, order =["Yes, Participated", "Yes, but did not Participate", "No"], 
#                  palette='winter').set_title("Finance Education In School or Company", fontsize = 16)
# # plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#Countplot of financial risk habits with respect to gender

# plt.figure(figsize = (12, 6))
sns.set(rc={"figure.figsize": (10, 7)})
ax = sns.countplot(x='finance_risk', data=eda,  order=["Not Risky at All", "Moderately Risky", "Risky", "Very Risky"], 
                 hue= 'gender', palette='Set1').set_title("Financial Risk Habits", fontsize = 16)

# %%
#Countplot of spending vs. income with respect to the year 2012, 2015

# plt.figure(figsize = (12, 6))
sns.set(rc={"figure.figsize": (10, 7)})
ax = sns.countplot(x='spending_vs_income', data=eda,  
                   order=["Spending < Income", "Spending = Income", "Spending > Income"], 
                   hue= 'year', palette='Set2').set_title("Spending vs. Income Habits", fontsize = 16)

# %%
#Bar graph of age categories
plt.figure(figsize = (12, 6))
ax = sns.countplot(x='age_group', data=eda, order = ["18-24 yo", "25-34 yo", "35-44 yo", "45-54 yo", "55-64 yo", "65+ yo"], 
                   facecolor=(0, 0, 0, 0), linewidth=5, edgecolor=sns.color_palette("dark", 3)).set_title("Age Groups", fontsize = 16)
plt.setp(alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-3ae4df55245b> in <module>()
#       3 ax = sns.countplot(x='age_group', data=eda, order = ["18-24 yo", "25-34 yo", "35-44 yo", "45-54 yo", "55-64 yo", "65+ yo"],
#       4                    facecolor=(0, 0, 0, 0), linewidth=5, edgecolor=sns.color_palette("dark", 3)).set_title("Age Groups", fontsize = 16)
# ----> 5 plt.setp(alpha=.5, linewidth=2, edgecolor="k")
#       6 plt.xticks(rotation=30)
#
# ~\AppData\Local\Continuum\anaconda3\New_folder\lib\site-packages\matplotlib\pyplot.py in setp(*args, **kwargs)
#     352 @docstring.copy(_setp)
#     353 def setp(*args, **kwargs):
# --> 354     return _setp(*args, **kwargs)
#     355
#     356
#
# TypeError: setp() missing 1 required positional argument: 'obj'

# %%
# bar graph of unpaid past due medical bills
ax = plt.subplot(111, xlabel='Count', ylabel='Unpaid Medical Bill Status', title='Do you have any unpaid medical bills?')
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(12)
    
top =eda.unpaid_pastdue_medical_bills.value_counts()
top.head(10).plot(kind='barh')

# %%
sns.violinplot(x=eda.ethnicity, y=eda.too_much_debt);

# %%
sns.histplot(x=eda.age_group, y=eda.year)
